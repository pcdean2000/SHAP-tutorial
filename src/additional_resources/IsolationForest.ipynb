# %%
# Imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import shap

from sklearn.ensemble import IsolationForest
from ucimlrepo import fetch_ucirepo

# Set figure background to white
plt.rcParams.update({'figure.facecolor':'white'})

# %% [markdown]
# # Data Cleaning and Feature Engineering

# %%
# Fetch dataset from UCI repository
power_consumption = fetch_ucirepo(id=235)

print(power_consumption.variables)
# Out:
# /mnt/e/Github/SHAP-tutorial/.venv/lib/python3.10/site-packages/ucimlrepo/fetch.py:97: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)
#                     name     role         type demographic description units  \
# 0                   Date  Feature         Date        None        None  None
# 1                   Time  Feature  Categorical        None        None  None
# 2    Global_active_power  Feature   Continuous        None        None  None
# 3  Global_reactive_power  Feature   Continuous        None        None  None
# 4                Voltage  Feature   Continuous        None        None  None
# 5       Global_intensity  Feature   Continuous        None        None  None
# 6         Sub_metering_1  Feature   Continuous        None        None  None
# 7         Sub_metering_2  Feature   Continuous        None        None  None
# 8         Sub_metering_3  Feature   Continuous        None        None  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3             no
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no

# %%
# Get all features
data = power_consumption.data.features
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')

# List of features to check
feature_columns = ['Global_active_power', 'Global_reactive_power', 'Voltage', 
                   'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']

# Convert feature columns to numeric and replace any errors with NaN
data[feature_columns] = data[feature_columns].apply(pd.to_numeric, errors='coerce')

# Drop rows where all feature columns are missing (NaN) 
data_cleaned = data.dropna(subset=feature_columns, how='all')

# Drop rows where ALL feature columns are NaN
data_cleaned.head()
# Out:
#         Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16  17:24:00                4.216                  0.418   234.84
# 1 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2 2006-12-16  17:26:00                5.374                  0.498   233.29
# 3 2006-12-16  17:27:00                5.388                  0.502   233.74
# 4 2006-12-16  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
# Group by 'Date' and calculate mean and standard deviation (ignore NaN values)
data_aggregated = data_cleaned.groupby('Date')[feature_columns].agg(['mean', 'std'])

# Rename columns to the desired format (MEAN_ColumnName, STD_ColumnName)
data_aggregated.columns = [
    f'{agg_type.upper()}_{col}' for col, agg_type in data_aggregated.columns
]

# Reset the index
data_aggregated.reset_index(inplace=True)

# Display the result
print(data_aggregated.shape)
data_aggregated.head()
# Out:
# (1433, 15)
#         Date  MEAN_Global_active_power  STD_Global_active_power  \
# 0 2006-12-16                  3.053475                 1.026338
# 1 2006-12-17                  2.354486                 1.205795
# 2 2006-12-18                  1.530435                 1.005074
# 3 2006-12-19                  1.157079                 1.237602
# 4 2006-12-20                  1.545658                 1.320968
#
#    MEAN_Global_reactive_power  STD_Global_reactive_power  MEAN_Voltage  \
# 0                    0.088187                   0.099014    236.243763
# 1                    0.156949                   0.114873    240.087028
# 2                    0.112356                   0.109154    241.231694
# 3                    0.104821                   0.101591    241.999313
# 4                    0.111804                   0.094926    242.308062
#
#    STD_Voltage  MEAN_Global_intensity  STD_Global_intensity  \
# 0     2.922896              13.082828              4.283262
# 1     4.051467               9.999028              5.031445
# 2     3.719576               6.421667              4.248511
# 3     3.069492               4.926389              5.238010
# 4     3.345704               6.467361              5.556587
#
#    MEAN_Sub_metering_1  STD_Sub_metering_1  MEAN_Sub_metering_2  \
# 0             0.000000            0.000000             1.378788
# 1             1.411806            6.813244             2.907639
# 2             0.738194            4.999534             1.820139
# 3             0.582639            4.459545             5.279167
# 4             0.000000            0.000000             1.838889
#
#    STD_Sub_metering_2  MEAN_Sub_metering_3  STD_Sub_metering_3
# 0            5.158545            12.439394            7.455105
# 1            8.800654             9.264583            8.645364
# 2            6.746395             9.734722            8.765125
# 3           12.771085             4.303472            7.529344
# 4            7.084353             9.765972            8.799051

# %% [markdown]
# # Train IsolationForest

# %%
# Parameters
n_estimators = 100  # Number of trees
sample_size = 256  # Number of samples used to train each tree
contamination = 0.02  # Expected proportion of anomalies

# %%
# Select Features
features = data_aggregated.drop('Date', axis=1)

# Train Isolation Forest
iso_forest = IsolationForest(n_estimators=n_estimators, 
                             contamination=contamination, 
                             max_samples=sample_size,
                             random_state=42)

iso_forest.fit(features)
# Out:
# /mnt/e/Github/SHAP-tutorial/.venv/lib/python3.10/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.02, max_samples=256, random_state=42)

# %%
data_aggregated['anomaly_score'] = iso_forest.decision_function(features)
data_aggregated['anomaly'] = iso_forest.predict(features)

data_aggregated['anomaly'].value_counts()
# Out:
#  1    1404
# -1      29
# Name: anomaly, dtype: int64

# %%
# Visualization of the results
plt.figure(figsize=(10, 5))

# Plot normal instances
normal = data_aggregated[data_aggregated['anomaly'] == 1]
plt.scatter(normal['Date'], normal['anomaly_score'], label='Normal')

# Plot anomalies
anomalies = data_aggregated[data_aggregated['anomaly'] == -1]
plt.scatter(anomalies['Date'], anomalies['anomaly_score'], label='Anomaly')

plt.xlabel("Instance")
plt.ylabel("Anomaly Score")
plt.legend()

# %% [markdown]
# # KernelSHAP with Anomaly Score

# %%
# Using the anomaly score and TreeSHAP (this code won't work)
explainer = shap.TreeExplainer(iso_forest, features)
shap_values = explainer(features)

# %%
# Select all anomalies and 100 random normal instances
normal_sample = np.random.choice(normal.index,size=100,replace=False)
sample = np.append(anomalies.index,normal_sample)

len(sample) # 129
# Out:
# 129

# %%
# Using the anomaly score and KernelSHAP
explainer = shap.Explainer(iso_forest.decision_function, features)
shap_values = explainer(features.iloc[sample])
# Out:
# PermutationExplainer explainer: 130it [02:08,  1.02s/it]

# %%
# Plot waterfall plot of an anomaly
shap.plots.waterfall(shap_values[0])

# %%
# Plot waterfall plot of a normal instance
shap.plots.waterfall(shap_values[100])

# %%
# MeanSHAP Plot
shap.plots.bar(shap_values)

# %%
# Beeswarm plot
shap.plots.beeswarm(shap_values)

# %% [markdown]
# # TreeSHAP with Path Length

# %%
# Calculate SHAP values
explainer = shap.TreeExplainer(iso_forest)
shap_values = explainer(features)

# %%
# Waterfall plot for an anomaly
shap.plots.waterfall(shap_values[0])

# %%
# Waterfall plot for a normal instance
shap.plots.waterfall(shap_values[2])

# %%
# Calculate f(x)
path_length = shap_values.base_values + shap_values.values.sum(axis=1)

# Get f(x) for anomalies and normal instances
anomalies = data_aggregated[data_aggregated['anomaly'] == -1]
path_length_anomalies = path_length[anomalies.index]

normal = data_aggregated[data_aggregated['anomaly'] == 1]
path_length_normal = path_length[normal.index]

# Plot boxplots for f(x)
plt.figure(figsize=(10, 5))
plt.boxplot([path_length_anomalies, path_length_normal], labels=['Anomaly','Normal'])
plt.ylabel("Average Path Length f(x)")
# Out:
# Text(0, 0.5, 'Average Path Length f(x)')

# %%
# MeanSHAP
shap.plots.bar(shap_values)

# %%
# MeanSHAP
shap.plots.beeswarm(shap_values)

# %%
# Interaction values
shap_interaction_values = explainer.shap_interaction_values(features)

# %%
# Get absolute mean of matrices
mean_shap = np.abs(shap_interaction_values).mean(0)
mean_shap = np.round(mean_shap, 1)

df = pd.DataFrame(mean_shap, index=features.columns, columns=features.columns)

# Times off diagonal by 2
df.where(df.values == np.diagonal(df), df.values * 2, inplace=True)

# Display
sns.set(font_scale=1)
sns.heatmap(df, cmap="coolwarm", annot=True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5]),
#  [Text(0, 0.5, 'MEAN_Global_active_power'),
#   Text(0, 1.5, 'STD_Global_active_power'),
#   Text(0, 2.5, 'MEAN_Global_reactive_power'),
#   Text(0, 3.5, 'STD_Global_reactive_power'),
#   Text(0, 4.5, 'MEAN_Voltage'),
#   Text(0, 5.5, 'STD_Voltage'),
#   Text(0, 6.5, 'MEAN_Global_intensity'),
#   Text(0, 7.5, 'STD_Global_intensity'),
#   Text(0, 8.5, 'MEAN_Sub_metering_1'),
#   Text(0, 9.5, 'STD_Sub_metering_1'),
#   Text(0, 10.5, 'MEAN_Sub_metering_2'),
#   Text(0, 11.5, 'STD_Sub_metering_2'),
#   Text(0, 12.5, 'MEAN_Sub_metering_3'),
#   Text(0, 13.5, 'STD_Sub_metering_3')])
